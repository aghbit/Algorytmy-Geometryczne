# %%
from main import Visualizer
import numpy as np

# %%
vis = Visualizer()
vis.show()

# %%
vis.add_points([(1,1), (0,0), (1,0)], color="red")

points = np.array([[1,2],
                   [3,4],
                   [5,6]])

vis.add_points(points=points, color="blue")

# %%
vis.show()

# %% [markdown]
# add_line_segments

# %%
vis.add_line_segments([[(0,1), (1,0)], np.array([[0,0], [7,7]])])

lines = np.array(
    [
        [[1,5], [5,1]],
        [[3,3], [4,5]],
        [[6,9], [9,6]],
        [[1,4], [5,1]]
    ]
)
vis.add_line_segments(lines, color="magenta")

vis.show()

# %%
vis.add_polygons([[[0,0],[8,1],[7,6]], [[2,3],[2,4],[6,0]]], color="green")
vis.show()

# %%
vis.save_picture("some_name")

# %%
vis.show()

vis.save_plot("my_plot")
vis.open_plot("my_plot")

vis.show()

# %%
vis.clear()
vis.add_polygons([[[-2,-2], [2,-2], [2,2], [-2,2]]])
vis.new_frame()
vis.add_points([[-1,0]])
vis.new_frame()
vis.add_points([[0,0]])
vis.new_frame()
vis.add_points([[1,0]])
vis.new_frame()
vis.make_gif()
vis.save_gif("my_gif.gif")
# vis.add_points(points=points, color="black")
# vis.show()
